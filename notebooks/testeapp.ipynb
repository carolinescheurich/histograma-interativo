# %%
import os
import pandas as pd
import plotly.express as px
import streamlit as st

# Caminho relativo: sobe um nível (..), depois entra em 'dados'
csv_path = os.path.join("..", "dados", "vehicles.csv")

# Carrega o CSV
car_data = pd.read_csv(csv_path)

hist_button = st.button('Criar histograma') # criar um botão
        
if hist_button: # se o botão for clicado
    # escrever uma mensagem
    st.write('Criando um histograma para o conjunto de dados de anúncios de vendas de carros')
            
    # criar um histograma
    fig = px.histogram(car_data, x="odometer")
        
    # exibir um gráfico Plotly interativo
    st.plotly_chart(fig, use_container_width=True)

# criar uma caixa de seleção
build_histogram = st.checkbox('Criar um histograma')

if build_histogram: # se a caixa de seleção for selecionada
    # escrever uma mensagem
    st.write('Criando um histograma para a coluna odometer')

    # criar um histograma
    fig = px.histogram(car_data, x="odometer")

    # exibir um gráfico Plotly interativo
    st.plotly_chart(fig, use_container_width=True)

# Configuração do Streamlit
st.set_page_config(page_title="Histograma Interativo", layout="wide")
st.title("Histograma Interativo de Vendas de Carros")
st.sidebar.header("Configurações do Histograma")
st.sidebar.write("Use os botões e caixas de seleção para criar histogramas interativos com os dados de vendas de carros.")
# Exibir os dados
st.sidebar.subheader("Dados de Vendas de Carros")
st.sidebar.dataframe(car_data.head(10), width=300, height=200)
# Exibir informações sobre o projeto
st.sidebar.subheader("Sobre o Projeto")
st.sidebar.write("Este projeto tem o intuito de criar histogramas interativos com os dados de vendas de carros. Você pode explorar os dados e visualizar a distribuição dos odômetros dos veículos.")
# Out:
# 2025-08-20 08:18:45.342 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 08:18:45.343 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 08:18:45.344 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 08:18:45.344 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 08:18:45.345 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 08:18:45.345 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 08:18:45.346 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 08:18:45.346 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 08:18:45.347 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 08:18:45.347 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 08:18:45.348 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 08:18:45.348 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 08:18:45.350 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 08:18:45.352 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 08:18:45.353 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 08:18:45.353 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 08:18:45.354 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 08:18:45.355 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 08:18:45.355 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 08:18:45.358 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 08:18:45.359 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 08:18:45.360 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 08:18:45.361 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 08:18:45.361 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 08:18:45.362 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 08:18:45.442 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 08:18:45.442 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 08:18:45.444 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 08:18:45.445 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 08:18:45.446 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 08:18:45.446 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 08:18:45.447 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 08:18:45.447 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-20 08:18:45.448 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
